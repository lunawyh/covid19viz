# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
frame = cv2.imread('./test_images/Priti-Patel-re-sized.jpg')
frame.shape
# Out:
# (1250, 2000, 3)

# %%
plt.imshow(frame)

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1250, 2000)

# %%
gray
# Out:
# array([[182, 182, 182, ...,  93,  93,  93],
#        [182, 182, 182, ...,  94,  94,  94],
#        [182, 182, 183, ...,  94,  94,  94],
#        ...,
#        [195, 195, 195, ..., 100, 100, 100],
#        [195, 195, 195, ..., 101, 101, 101],
#        [193, 193, 193, ..., 102, 102, 102]], dtype=uint8)

# %%
plt.imshow(gray, cmap= 'gray')

# %%
import cv2
import sys

# Get user supplied values
imagePath = ('./test_images/Priti-Patel-re-sized.jpg')
cascPath = "haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.cv.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2.imshow("Faces found", image)
cv2.waitKey(0)
